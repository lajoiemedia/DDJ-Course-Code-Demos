# %%
# Import relevant libraries for use
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_trees = pd.read_csv("data/raw/Urban_Forestry_Street_Trees.csv")
df_trees
# Out:
# /var/folders/y1/p9d43pdn5s5fzxn0ncrl6s500000gq/T/ipykernel_55455/45977485.py:1: DtypeWarning: Columns (35,36,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_trees = pd.read_csv("data/raw/Urban_Forestry_Street_Trees.csv")
#                 X          Y                          SCI_NM  \
# 0      -77.043266  38.935030                 Ulmus americana
# 1      -77.046241  38.934183                             NaN
# 2      -77.041350  38.932896                 Ulmus americana
# 3      -77.044637  38.932823  Ulmus americana 'Valley Forge'
# 4      -77.043090  38.930634                  Acer saccharum
# ...           ...        ...                             ...
# 209973 -76.999449  38.883817                             NaN
# 209974 -76.953893  38.894555           Platanus occidentalis
# 209975 -76.954158  38.894303           Platanus occidentalis
# 209976 -76.931400  38.886346                     Pinus taeda
# ...

# %%
df_trees["EDITEDBY"].value_counts()
# Out:
# EDITEDBY
# cklapthor        13940
# dmalooly         11534
# mlehtonen        10870
# agrieve          10782
# jburckle         10397
# eanderson        10278
# ymagarik          9731
# jconlon           9468
# sbanua            9352
# jbrew             8761
# smckim            8338
# mmcphee           8218
# mchuko            7598
# rbabra            7298
# abenjamin         6907
# aaleksiev         6719
# sward             5639
# jmiller           5522
# mtan              5405
# rdelsack          4405
# aroth             3976
# sdoan             3487
# djust             3465
# msampson          2905
# jchapman          2798
# jbiddle           2739
# mertem            2153
# rcorletta         1948
# rschwartz         1897
# ufaarborist       1341
# rdmccully         1335
# bcantwell         1285
# eclymirestern      910
# mgreenberg         833
# joneill            740
# mfish              647
# jpond              489
# arowe              408
# khout              322
# ...
